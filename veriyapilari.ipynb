# %% [markdown]
# <a href="https://colab.research.google.com/github/EdaOzgeUgurlu/python/blob/main/veriyapilari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🧠 Temel Kavramlar
# 🔹 Algoritma Nedir?
# Adım adım bir problemi çözen veya bir işlemi gerçekleştiren talimatlar dizisidir.
# 📌 Örn: Yemek tarifi de bir algoritmadır.

# 🔹 Bilgisayar Bilgisayarda İfade
# Bilgisayarlar verileri ikili (0 ve 1) biçiminde işler. Metin, ses, resim gibi her veri bu şekilde ifade edilir.

# 🔹 Sayı Sistemleri
# İkili (Binary): 0, 1

# Onluk (Decimal): 0-9

# Onaltılık (Hexadecimal): 0-9 ve A-F

# 🔹 Sayısal Olmayan Verilerin Saklanması
# Metinler (ASCII, Unicode), görseller (JPEG, PNG) gibi veriler de ikili biçimde kodlanır.

# 🔹 Verilerin Kullanımı
# Veriler işlenir, analiz edilir ve anlamlı hale getirilir. Örn: Sensör verileriyle sıcaklık tahmini yapılabilir.

# 🔹 Hesaplama
# Veriler üzerinde işlem yaparak sonuç elde etmektir. Örn: Toplama, çarpma gibi işlemler.

# 🧩 Veri Yapıları
# 🔹 Array (Dizi)
# Aynı türden verileri saklayan sabit boyutlu yapı.
# 📌 arr = [1, 2, 3]

# 🔹 Linked List
# Düğümlerden oluşur, her düğüm veriyi ve bir sonraki düğüme bağlantıyı (pointer) tutar.

# 🔹 Linked List vs Array
# Array: İndeksle erişim hızlı, ama ekleme/silme yavaş.

# Linked List: Ekleme/silme kolay, ama erişim yavaş.

# 🔹 Linked List Eleman Ekleme/Silme
# Bağlantılar (pointer) güncellenerek yapılır.

# 🔹 Stack
# LIFO (Last In First Out) yapısı.
# 📌 push(), pop()

# 🔹 Queue
# FIFO (First In First Out) yapısı.
# 📌 enqueue(), dequeue()

# 🔹 Hash Table
# Anahtar-değer (key-value) çiftleri tutar.
# 📌 dict yapısı gibi.

# 🔹 Hash Function
# Bir veriyi (key) alır ve ona özgü bir sayı üretir. Bu sayı tabloya yerleştirme için kullanılır.

# 🔹 Hash Collision
# Farklı iki anahtarın aynı index’e denk gelmesi. Çözüm: chaining, open addressing vs.

# 🧮 Algoritma Analizi
# 🔹 Algoritma Analizi Giriş
# Verimlilik ve performans ölçülür: Zaman ve alan karmaşıklığı.

# 🔹 RAM Modeli
# Her işlemin sabit zaman aldığı ideal bir hesaplama modeli.

# 🔹 Time Complexity (Zaman Karmaşıklığı)
# Kodun çalışmasının giriş büyüklüğüne göre süresi.
# 📌 Örn: O(n), O(n^2), O(log n)

# 🔹 Big O Notation
# En kötü durum analizidir. Karmaşıklık türünü belirtir.

# 🔄 Sorting (Sıralama) Algoritmaları
# 🔹 Sorting Nedir?
# Verileri belirli bir sıraya (küçükten büyüğe gibi) dizmektir.

# 🔹 Selection Sort
# Her turda minimum değeri bulup başa alır.
# 📌 Karmaşıklık: O(n^2)

# 🔹 Merge Sort
# Veriyi ikiye böl, sırala, birleştir.
# 📌 Karmaşıklık: O(n log n)

# 🔹 Quick Sort
# Pivot seç, küçükleri sola, büyükleri sağa al.
# 📌 Karmaşıklık: Ortalama O(n log n), kötü O(n^2)

# 🔍 Searching (Arama) Algoritmaları
# 🔹 Searching Nedir?
# Veri içinde belirli bir öğeyi bulma işlemidir.

# 🔹 Linear Search
# Baştan sona sırayla arar.
# 📌 Karmaşıklık: O(n)

# 🔹 Binary Search
# Sıralı veride ortayı kontrol ederek yarı yarıya indirir.
# 📌 Karmaşıklık: O(log n)

# 🔹 Binary Search Tree
# Her düğüm solundakilerden büyük, sağındakilerden küçük. Hızlı arama sağlar.

# 💼 Projeler (Uygulamalar)
# 🔹 Iteration Sort Projesi
# Kendi Selection veya Insertion Sort algoritmanı yaz ve veri sıralaması yap.

# 🔹 Binary Search Projesi
# Bir dizi içinde kullanıcıdan alınan sayının olup olmadığını Binary Search ile bul.

# 🔹 Binary Search Tree Projesi
# Bir BST oluştur, düğüm ekleme, silme ve arama işlemlerini uygula.
