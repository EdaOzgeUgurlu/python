# %% [markdown]
# <a href="https://colab.research.google.com/github/EdaOzgeUgurlu/python/blob/main/python101gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📌 PROGRAMLAMA NEDİR?
# Bilgisayara belirli görevleri yaptırmak için yazılan komutlar bütünüdür. Python gibi dillerle bu komutlar yazılır.

# 📌 JUPYTER NOTEBOOK
# Python kodlarını hücre hücre çalıştırabileceğin bir arayüzdür. Google Colab de Jupyter tabanlıdır.

# 📌 TEMEL VERİ TİPLERİ
x = 10          # int (tam sayı)
y = 3.14        # float (ondalıklı)
z = "merhaba"   # str (metin)
a = True        # bool (mantıksal)

# 📌 DEĞİŞKEN ATAMA
isim = "Eda"
yas = 30

# 📌 OPERATÖRLER VE İFADELER
a = 5
b = 2
toplam = a + b    # +, -, *, /, //, %, **

# 📌 STRİNGLER
metin = "Python öğreniyorum"

# 📌 STRİNGLER ÜZERİNDE OPERATÖRLER
print("Python" + " " + "Rocks")  # birleştirme
print("Ha" * 3)                 # tekrar

# 📌 STRİNGLERDE INDEXLEME
isim = "EDA"
print(isim[0])     # 'E'
print(isim[-1])    # 'A'

# 📌 STRİNGLERDE CASTING
sayi = "42"
print(int(sayi) + 1)  # 43

# 📌 INPUT
ad = input("Adınız: ")
print("Merhaba", ad)

# 📌 KODA YORUM EKLEME
# Bu bir yorum satırıdır, kodu etkilemez.

# 📌 SAYISAL VERİLERDE KARŞILAŞTIRMA
print(5 > 3)   # True

# 📌 STRİNGLERDE KARŞILAŞTIRMA
print("abc" == "abc")  # True

# 📌 MANTIKSAL OPERATÖRLER
print(True and False)  # False
print(True or False)   # True
print(not True)        # False

# 📌 SHORT-CIRCUIT OLMAYAN MANTIKSAL OPERATÖRLER
# Python'da `and` ve `or` kısa devre yapar.
a = False and print("Çalışmaz")
b = True or print("Yine çalışmaz")

# 📌 IF - ELIF - ELSE
yas = 18
if yas < 18:
    print("Çocuk")
elif yas == 18:
    print("Tam 18")
else:
    print("Yetişkin")

# 📌 TERNARY CONDITIONALS
x = 5
sonuc = "pozitif" if x > 0 else "negatif"
print(sonuc)

# 📌 DÖNGÜLER
# WHILE
i = 0
while i < 3:
    print(i)
    i += 1

# FOR
for harf in "EDA":
    print(harf)

# 📌 CONTINUE / BREAK
for i in range(5):
    if i == 2:
        continue
    if i == 4:
        break
    print(i)

# 📌 LIST
meyveler = ["elma", "muz", "çilek"]

# 📌 TUPLE
koordinat = (10, 20)

# 📌 IN
print("muz" in meyveler)  # True

# 📌 DICTIONARY
kisi = {"ad": "Eda", "yas": 30}
print(kisi["ad"])

# 📌 SET
renkler = {"kırmızı", "mavi", "yeşil"}

# 📌 NON-SCALAR VERİ TİPLERİNDE FOR
for meyve in meyveler:
    print(meyve)

# 📌 SPLIT / JOIN
cumle = "Bugün hava güzel"
kelimeler = cumle.split()
print(kelimeler)
birlesik = " ".join(kelimeler)
print(birlesik)

# 📌 LIST COMPREHENSION
sayilar = [i for i in range(5)]
print(sayilar)

# 📌 VARIABLE UNPACKING
x, y = (1, 2)
print(x, y)

# 📌 ENUMERATE / ZIP
liste = ["a", "b", "c"]
for i, harf in enumerate(liste):
    print(i, harf)

sayilar = [1, 2, 3]
harfler = ["bir", "iki", "üç"]
for s, h in zip(sayilar, harfler):
    print(s, h)

# 📌 FONKSİYONLAR
def selamla(ad):
    print(f"Merhaba {ad}")

selamla("Eda")

# 📌 RETURN
def kare(x):
    return x * x

print(kare(4))  # 16

# 📌 COMMENT FONKSİYON
def bilgi():
    """
    Bu fonksiyon ekrana bilgi yazar.
    """
    print("Fonksiyon çalıştı")

# 📌 BİRDEN FAZLA DEĞER DÖNDÜRME
def islemler(a, b):
    return a + b, a * b

toplam, carpim = islemler(2, 3)
print(toplam, carpim)

# 📌 PREDEFINED PARAMETERS
def selam(ad="Ziyaretçi"):
    print(f"Merhaba {ad}")

selam()
selam("Eda")

# 📌 UPDATE INPUT
def yas_guncelle(yas):
    return yas + 1

# 📌 FIRST CLASS FUNCTION
def topla(x, y):
    return x + y

def isle(yontem, a, b):
    return yontem(a, b)

print(isle(topla, 2, 3))

# 📌 FOR FUNCTION
def tekrarla(fonk, n):
    for _ in range(n):
        fonk()

tekrarla(lambda: print("Tekrar!"), 3)

# 📌 UNDERSCORE PLACEHOLDER
a, _, c = (1, 2, 3)
print(a, c)

# 📌 F-STRING
ad = "Eda"
yas = 30
print(f"{ad} {yas} yaşındadır.")
# Out:
# Python Rocks
# HaHaHa
# E
# A
# 43
# Adınız: 35
# Merhaba 35
# True
# True
# False
# True
# False
# Tam 18
# pozitif
# 0
# 1
# 2
# E
# D
# A
# 0
# 1
# 3
# True
# Eda
# elma
# muz
# çilek
# ['Bugün', 'hava', 'güzel']
# Bugün hava güzel
# [0, 1, 2, 3, 4]
# 1 2
# 0 a
# 1 b
# 2 c
# 1 bir
# 2 iki
# 3 üç
# Merhaba Eda
# 16
# 5 6
# Merhaba Ziyaretçi
# Merhaba Eda
# 5
# Tekrar!
# Tekrar!
# Tekrar!
# 1 3
# Eda 30 yaşındadır.
